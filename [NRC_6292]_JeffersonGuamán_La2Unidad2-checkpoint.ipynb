# %%
'''Primero se importan los módulos necesarios para el desarrollo del algoritmo'''
import pandas as pd

# %%
'''Cargamos el conjunto de datos'''
df = pd.read_csv('data_act_01.csv', sep=';')
'''Imprimimos y vizualizamos el conjunto de datos'''
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# 1      2016-03-31T15:31:00           GOA  2300 Block Of Market St
# 2      2016-03-31T16:49:00           GOA  2300 Block Of Market St
# 3      2016-03-31T17:38:00           GOA      500 Block Of 7th St
# 4      2016-03-31T17:42:00           REP       Beale St/bryant St
# ...                    ...           ...                      ...
# 10046  2016-04-05T23:38:00           GOA    Hollister Av/hawes St
# 10047  2016-04-05T23:43:00           ADV   California St/mason St
# 10048  2016-04-05T23:48:00           CIT   Rosella Ct/onondaga Av
# 10049  2016-04-05T23:48:00  Not recorded          0 Blk Herbst Rd
# 10050  2016-04-05T23:54:00           ADV        Grant Av/geary St
#
#                 City State AgencyId  Range      AddressType
# 0      San Francisco    CA        1    NaN  Premise Address
# 1      San Francisco    CA        1    NaN  Premise Address
# 2      San Francisco    CA        1    NaN  Premise Address
# 3      San Francisco    CA        1    NaN  Premise Address
# 4      San Francisco    CA        1    NaN     Intersection
# ...              ...   ...      ...    ...              ...
# 10046  San Francisco    CA        1    NaN     Intersection
# 10047  San Francisco    CA        1    NaN     Intersection
# 10048  San Francisco    CA        1    NaN     Intersection
# 10049  San Francisco    CA        1    NaN     Geo-Override
# 10050  San Francisco    CA        1    NaN     Intersection
#
# [10051 rows x 12 columns]

# %%
""" obtener informacion de variables del dataset """
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CrimeId                10051 non-null  int64
#  1   OriginalCrimeTypeName  10051 non-null  object
#  2   OffenseDate            10051 non-null  object
#  3   CallTime               10051 non-null  object
#  4   CallDateTime           10051 non-null  object
#  5   Disposition            10051 non-null  object
#  6   Address                10051 non-null  object
#  7   City                   9730 non-null   object
#  8   State                  10048 non-null  object
#  9   AgencyId               10051 non-null  object
#  10  Range                  0 non-null      float64
#  11  AddressType            10051 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 942.4+ KB

# %% [markdown]
# # Primer error - Columna Range con valores NaN

# %%
'''Eliminamos la columna de Range junto con todos sus valores NaN'''
df.drop(['Range'], axis='columns', inplace=True)

# %%
'''Imprimimos y vizualizamos el conjunto de datos'''
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# 1      2016-03-31T15:31:00           GOA  2300 Block Of Market St
# 2      2016-03-31T16:49:00           GOA  2300 Block Of Market St
# 3      2016-03-31T17:38:00           GOA      500 Block Of 7th St
# 4      2016-03-31T17:42:00           REP       Beale St/bryant St
# ...                    ...           ...                      ...
# 10046  2016-04-05T23:38:00           GOA    Hollister Av/hawes St
# 10047  2016-04-05T23:43:00           ADV   California St/mason St
# 10048  2016-04-05T23:48:00           CIT   Rosella Ct/onondaga Av
# 10049  2016-04-05T23:48:00  Not recorded          0 Blk Herbst Rd
# 10050  2016-04-05T23:54:00           ADV        Grant Av/geary St
#
#                 City State AgencyId      AddressType
# 0      San Francisco    CA        1  Premise Address
# 1      San Francisco    CA        1  Premise Address
# 2      San Francisco    CA        1  Premise Address
# 3      San Francisco    CA        1  Premise Address
# 4      San Francisco    CA        1     Intersection
# ...              ...   ...      ...              ...
# 10046  San Francisco    CA        1     Intersection
# 10047  San Francisco    CA        1     Intersection
# 10048  San Francisco    CA        1     Intersection
# 10049  San Francisco    CA        1     Geo-Override
# 10050  San Francisco    CA        1     Intersection
#
# [10051 rows x 11 columns]

# %% [markdown]
# Para realizar un analisis de datos con valores null se dijita el sigueinte comando.

# %%
'''Verificar los valores null en los registros del dataset'''
df.isnull().sum()
# Out:
# CrimeId                    0
# OriginalCrimeTypeName      0
# OffenseDate                0
# CallTime                   0
# CallDateTime               0
# Disposition                0
# Address                    0
# City                     321
# State                      3
# AgencyId                   0
# AddressType                0
# dtype: int64

# %% [markdown]
# # Segundo error - Tratar los null de la columna city

# %%
'''Busqueda de registros de la columna city, tomando en cuenta los null'''
print(df['City'].value_counts(dropna=False))
# Out:
# San Francisco    9665
# NaN               321
# Treasure Isla      51
# Daly City           5
# Yerba Buena         3
# Presidio            3
# SAN FRANCISCO       1
#  S                  1
# Brisbane            1
# Name: City, dtype: int64

# %%
'''Seleccion de los datos null para la convercion a cero'''
df[['City']] = df[['City']].fillna(value=0)

# %%
'''Verificacion del cambio del tipo de registro Nan a cero'''
print(df['City'].value_counts(dropna=False))
# Out:
# San Francisco    9665
# 0                 321
# Treasure Isla      51
# Daly City           5
# Yerba Buena         3
# Presidio            3
# SAN FRANCISCO       1
#  S                  1
# Brisbane            1
# Name: City, dtype: int64

# %%
'''Verificar los valores null en los registros de la columna city'''
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    3
# AgencyId                 0
# AddressType              0
# dtype: int64

# %% [markdown]
# # Tercer error - Tratar los null  de la columna state

# %%
'''Busqueda de registros  de la columna state, tomando en cuenta los null'''
print(df['State'].value_counts(dropna=False))
# Out:
# CA     10048
# NaN        3
# Name: State, dtype: int64

# %%
'''Seleccion de los datos null para la convercion a cero'''
df[['State']] = df[['State']].fillna(value=0)

# %%
'''Verificacion del cambio del tipo de registro Nan a cero'''
print(df['State'].value_counts(dropna=False))
# Out:
# CA    10048
# 0         3
# Name: State, dtype: int64

# %%
'''Verificar los valores null en los registros de la columna state'''
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    0
# AgencyId                 0
# AddressType              0
# dtype: int64

# %% [markdown]
# # Cuarto error - Correccion de acronimos incorrectos

# %%
'''Busqueda de registros de la columna disposition'''
print(df['Disposition'].value_counts(dropna=False))
# Out:
# HAN             2820
# CIT             1425
# GOA             1273
# ADV             1142
# REP              800
# Not recorded     543
# ND               427
# UTL              385
# CAN              353
# NOM              324
# PAS              170
# ABA               97
# NCR               82
# 22                77
# ARR               65
# ADM               48
# INC               17
# CRT                2
# SFD                1
# Name: Disposition, dtype: int64

# %%
'''Realizo la modificacion del dato numerico incorrecto por uno del tipo texto'''
df['Disposition']= df['Disposition'].replace('22', 'AMZ')

# %%
'''Realizo la modificacion del dato Not recorded por otro'''
df['Disposition']= df['Disposition'].replace('Not recorded', 'NR')

# %%
'''Busqueda de registros de la columna disposition'''
print(df['Disposition'].value_counts(dropna=False))
# Out:
# HAN    2820
# CIT    1425
# GOA    1273
# ADV    1142
# REP     800
# NR      543
# ND      427
# UTL     385
# CAN     353
# NOM     324
# PAS     170
# ABA      97
# NCR      82
# AMZ      77
# ARR      65
# ADM      48
# INC      17
# CRT       2
# SFD       1
# Name: Disposition, dtype: int64

# %% [markdown]
# # Quinto error - Mayusculas y Minusculas

# %%
'''Imprimimos los registros de la columna city'''
df.groupby('City').count()
# Out:
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# 0                  321                    321          321       321
#  S                   1                      1            1         1
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# SAN FRANCISCO        1                      1            1         1
# San Francisco     9665                   9665         9665      9665
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  \
# City
# 0                       321          321      321    321       321
#  S                        1            1        1      1         1
# Brisbane                  1            1        1      1         1
# Daly City                 5            5        5      5         5
# Presidio                  3            3        3      3         3
# SAN FRANCISCO             1            1        1      1         1
# San Francisco          9665         9665     9665   9665      9665
# Treasure Isla            51           51       51     51        51
# Yerba Buena               3            3        3      3         3
#
#                AddressType
# City
# 0                      321
#  S                       1
# Brisbane                 1
# Daly City                5
# Presidio                 3
# SAN FRANCISCO            1
# San Francisco         9665
# Treasure Isla           51
# Yerba Buena              3

# %%
'''Cambio de los registros que tengan valor cero por San Francisco '''
df['City']= df['City'].replace(0, 'San Francisco')

# %%
'''Cambio de los registros que tengan valor S por San Francisco '''
df['City']= df['City'].replace(' S', 'San Francisco')

# %%
'''Cambio de los registros que tengan valor SAN FRANCISCO con mayusculas a minusculas'''
df['City']= df['City'].replace('SAN FRANCISCO' , 'San Francisco')

# %%
'''Imprimimos los registros de la columna city para ver los cambios realizados'''
df.groupby('City').count()
# Out:
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# San Francisco     9988                   9988         9988      9988
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  \
# City
# Brisbane                  1            1        1      1         1
# Daly City                 5            5        5      5         5
# Presidio                  3            3        3      3         3
# San Francisco          9988         9988     9988   9988      9988
# Treasure Isla            51           51       51     51        51
# Yerba Buena               3            3        3      3         3
#
#                AddressType
# City
# Brisbane                 1
# Daly City                5
# Presidio                 3
# San Francisco         9988
# Treasure Isla           51
# Yerba Buena              3

# %% [markdown]
# # Sexto error - Valores duplicados

# %%
'''Ver cuáles son los registros duplicados, utilizamos keep=False'''
df[df.duplicated('CrimeId', keep=False)]
# Out:
#         CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 26    160913455             Vandalism  2016-03-31T00:00:00    20:53
# 1707  160913455                  Susp  2016-04-01T00:00:00    18:29
# 3792  160913455          Passing Call  2016-04-02T00:00:00    17:11
# 7045  160950496          Passing Call  2016-04-04T00:00:00     6:51
# 7046  160950496    Suspicious Vehicle  2016-04-04T00:00:00     6:51
# 7047  160950496            Trespasser  2016-04-04T00:00:00     6:51
#
#              CallDateTime Disposition                     Address  \
# 26    2016-03-31T20:53:00          ND  1600 Block Of Sunnydale Av
# 1707  2016-04-01T18:29:00         GOA          Geary St/larkin St
# 3792  2016-04-02T17:11:00          NR      900 Block Of Market St
# 7045  2016-04-04T06:51:00         HAN     University St/felton St
# 7046  2016-04-04T06:51:00          ND   1400 Block Of Cabrillo St
# 7047  2016-04-04T06:51:00         CAN       Block Of Hampshire St
#
#                City State AgencyId      AddressType
# 26    San Francisco    CA        1  Premise Address
# 1707  San Francisco    CA        1     Intersection
# 3792  San Francisco    CA        1  Premise Address
# 7045  San Francisco    CA        1     Intersection
# 7046  San Francisco    CA        1  Premise Address
# 7047  San Francisco    CA        1  Premise Address

# %%
"""Eliminar registros obtenidos con datos duplicados"""
df.drop([26, 1707, 3792, 7045, 7046	, 7047], axis=0, inplace=True)

# %%
"""Compruebo la existencia de registros duplicados"""
df['CrimeId'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Septimo error - Columnas repetidas Fechas

# %%
'''Eliminamos la columna de OffenseDate junto con todos sus valores, para quedarnos con la fecha mas optima'''
df.drop(['OffenseDate'], axis='columns', inplace=True)

# %%
'''Eliminamos la columna de CallTime junto con todos sus valores, para quedarnos con la fecha mas optima'''
df.drop(['CallTime'], axis='columns', inplace=True)

# %%
'''Imprimimos y vizualizamos el conjunto de datos'''
df
# Out:
#          CrimeId OriginalCrimeTypeName         CallDateTime Disposition  \
# 0      160903280     Assault / Battery  2016-03-30T18:42:00         REP
# 1      160912272    Homeless Complaint  2016-03-31T15:31:00         GOA
# 2      160912590             Susp Info  2016-03-31T16:49:00         GOA
# 3      160912801                Report  2016-03-31T17:38:00         GOA
# 4      160912811                   594  2016-03-31T17:42:00         REP
# ...          ...                   ...                  ...         ...
# 10046  160964210      Well Being Check  2016-04-05T23:38:00         GOA
# 10047  160964216          Traffic Stop  2016-04-05T23:43:00         ADV
# 10048  160964227          Traffic Stop  2016-04-05T23:48:00         CIT
# 10049  160964229          Passing Call  2016-04-05T23:48:00          NR
# 10050  160964249          Traffic Stop  2016-04-05T23:54:00         ADV
#
#                        Address           City State AgencyId      AddressType
# 0      100 Block Of Chilton Av  San Francisco    CA        1  Premise Address
# 1      2300 Block Of Market St  San Francisco    CA        1  Premise Address
# 2      2300 Block Of Market St  San Francisco    CA        1  Premise Address
# 3          500 Block Of 7th St  San Francisco    CA        1  Premise Address
# 4           Beale St/bryant St  San Francisco    CA        1     Intersection
# ...                        ...            ...   ...      ...              ...
# 10046    Hollister Av/hawes St  San Francisco    CA        1     Intersection
# 10047   California St/mason St  San Francisco    CA        1     Intersection
# 10048   Rosella Ct/onondaga Av  San Francisco    CA        1     Intersection
# 10049          0 Blk Herbst Rd  San Francisco    CA        1     Geo-Override
# 10050        Grant Av/geary St  San Francisco    CA        1     Intersection
#
# [10045 rows x 9 columns]

# %% [markdown]
# # Octavo error - Columna AddressType

# %%
"""Verifico los valores unicos de la columna AddressType """
df['AddressType'].unique()
# Out:
# array(['Premise Address', 'Intersection', 'Common Location',
#        'Geo-Override', 'Intersectioon', '1'], dtype=object)

# %%
'''Cambio en la columna AddressType, de Intersectioon a Intersection'''
df['AddressType'] = df['AddressType'].replace('Intersectioon', 'Intersection')
df['AddressType'].unique()
# Out:
# array(['Premise Address', 'Intersection', 'Common Location',
#        'Geo-Override', '1'], dtype=object)

# %%
'''Imprimimos y vizualizamos el conjunto de datos'''
df
# Out:
#          CrimeId OriginalCrimeTypeName         CallDateTime Disposition  \
# 0      160903280     Assault / Battery  2016-03-30T18:42:00         REP
# 1      160912272    Homeless Complaint  2016-03-31T15:31:00         GOA
# 2      160912590             Susp Info  2016-03-31T16:49:00         GOA
# 3      160912801                Report  2016-03-31T17:38:00         GOA
# 4      160912811                   594  2016-03-31T17:42:00         REP
# ...          ...                   ...                  ...         ...
# 10046  160964210      Well Being Check  2016-04-05T23:38:00         GOA
# 10047  160964216          Traffic Stop  2016-04-05T23:43:00         ADV
# 10048  160964227          Traffic Stop  2016-04-05T23:48:00         CIT
# 10049  160964229          Passing Call  2016-04-05T23:48:00          NR
# 10050  160964249          Traffic Stop  2016-04-05T23:54:00         ADV
#
#                        Address           City State AgencyId      AddressType
# 0      100 Block Of Chilton Av  San Francisco    CA        1  Premise Address
# 1      2300 Block Of Market St  San Francisco    CA        1  Premise Address
# 2      2300 Block Of Market St  San Francisco    CA        1  Premise Address
# 3          500 Block Of 7th St  San Francisco    CA        1  Premise Address
# 4           Beale St/bryant St  San Francisco    CA        1     Intersection
# ...                        ...            ...   ...      ...              ...
# 10046    Hollister Av/hawes St  San Francisco    CA        1     Intersection
# 10047   California St/mason St  San Francisco    CA        1     Intersection
# 10048   Rosella Ct/onondaga Av  San Francisco    CA        1     Intersection
# 10049          0 Blk Herbst Rd  San Francisco    CA        1     Geo-Override
# 10050        Grant Av/geary St  San Francisco    CA        1     Intersection
#
# [10045 rows x 9 columns]

# %% [markdown]
# # Formato JSON

# %%
'''Transformamos el dataset de tipo csv a json'''
df.to_json('data_act_01_Limpieza.json', orient='records', lines=True)
